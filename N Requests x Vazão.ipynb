# %%
# Importando as dependências
from QKDnet.components import Network, Controller
from QKDnet.sim import Simulation
from QKDnet.utils import Logger

# Ativar os logs:
# Logger.activate(Logger)

# %%
# Rede
rede = Network()
rede.set_topology("Lattice", 3,4)
rede.set_nqubits(1000)
rede.draw()
# Controlador
controlador = Controller(rede)

# %%
# Parâmetros da simulação
n_requests = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]
apps_distribution = [0.33, 0.33, 0.33]
max_time_request = 10
simulation_case = 1

# %%
# Ordenador
controlador.set_sorter('urgency')

# Simulações
simulations = []

for n in n_requests:
    sim = Simulation(rede, controlador)
    sim.set_case(simulation_case)
    sim.set_apps_distribution(apps_distribution)
    sim.set_max_time_request(max_time_request)
    # Alterando o número de requests
    sim.set_n_requests(n)
    sim.run()
    # Guardando a simulação
    simulations.append(sim)

# %%
for simulation in simulations:
    print(simulation.throughput)
# Out:
# 5.266666666666667
# 4.870967741935484
# 4.553191489361702
# 4.507936507936508
# 4.518987341772152
# 4.442105263157894
# 4.306306306306307
# 4.25984251968504
# 4.223776223776224
# 4.2075471698113205
